# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# #### Observations:
#
# * Temperature tends to be higher in cities located near the equator, and lower in cities located far from the equator. The further a city is from the equator, the lower the temperature.
#
# * Based on the scatter plot, it appears that humidity tends to be high in cities with latitudes between -20 degrees and 0 degrees, and between 60 degrees and 80 degrees. However, the correlation analysis did not reveal a correlation between humidity and latitude.
#
# * Cloudiness and wind speed tend to vary greatly at all latitudes. The correlation analysis did not reveal any correlations between cloudiness and latitude, or between wind speed and latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "data_output/cities_output.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
# Create lists to hold weather data for cities:

City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_temp = []
Wind_speed = []

# Build query url:

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Perform API calls to retrieve weather data for all cities:

for index, city in enumerate(cities):
    
    try:
        response = requests.get(query_url + city).json()
        
        Cloudiness.append(response["clouds"]["all"])
        Country.append(response["sys"]["country"])
        Date.append(response["dt"])
        Humidity.append(response["main"]["humidity"])
        Lat.append(response["coord"]["lat"])
        Lng.append(response["coord"]["lon"])
        Max_temp.append(response["main"]["temp_max"])
        Wind_speed.append(response["wind"]["speed"])
        City.append(city)
        
        print("Processing Record " + str(index) + " | " + city)
        
    except:  
        print("Could Not Process Record " + str(index) + " | " + "City not found")
# Out:
# Processing Record 0 | port elizabeth
# Processing Record 1 | sandwick
# Processing Record 2 | new norfolk
# Processing Record 3 | chokwe
# Processing Record 4 | muros
# Processing Record 5 | lata
# Processing Record 6 | lockhart
# Processing Record 7 | blythe
# Processing Record 8 | ribeira grande
# Processing Record 9 | pangody
# Processing Record 10 | hermanus
# Processing Record 11 | kapaa
# Processing Record 12 | longyearbyen
# Could Not Process Record 13 | City not found
# Processing Record 14 | coos bay
# Processing Record 15 | clyde river
# Processing Record 16 | kodiak
# Processing Record 17 | yellowknife
# Processing Record 18 | albany
# Processing Record 19 | belvedere marittimo
# Processing Record 20 | dikson
# Processing Record 21 | port alfred
# Processing Record 22 | bluff
# Processing Record 23 | hamilton
# Processing Record 24 | jamestown
# Processing Record 25 | ketchikan
# Processing Record 26 | aginskoye
# Processing Record 27 | thunder bay
# Processing Record 28 | kruisfontein
# Could Not Process Record 29 | City not found
# Processing Record 30 | nikolskoye
# Processing Record 31 | port hardy
# Processing Record 32 | copiapo
# Processing Record 33 | punta arenas
# Processing Record 34 | esperance
# Processing Record 35 | escanaba
# Processing Record 36 | sao joao da barra
# Processing Record 37 | vaini
# Processing Record 38 | chokurdakh
# Processing Record 39 | victoria
# Processing Record 40 | grindavik
# Processing Record 41 | marzuq
# Processing Record 42 | mahebourg
# Processing Record 43 | flinders
# Could Not Process Record 44 | City not found
# Processing Record 45 | cabo san lucas
# Processing Record 46 | busselton
# Could Not Process Record 47 | City not found
# Processing Record 48 | battle creek
# Processing Record 49 | santiago do cacem
# Processing Record 50 | saint-philippe
# Processing Record 51 | oktyabrskiy
# Processing Record 52 | rikitea
# Processing Record 53 | barrow
# Processing Record 54 | jining
# Processing Record 55 | avarua
# Processing Record 56 | nanortalik
# Processing Record 57 | bambous virieux
# Processing Record 58 | ushuaia
# Processing Record 59 | airai
# Processing Record 60 | rawson
# Processing Record 61 | zhezkazgan
# Processing Record 62 | lhokseumawe
# Processing Record 63 | bandarbeyla
# Processing Record 64 | kaitangata
# Processing Record 65 | kuytun
# Processing Record 66 | castro
# Processing Record 67 | saint-pierre
# Processing Record 68 | hilo
# Processing Record 69 | victor harbor
# Processing Record 70 | hobyo
# Processing Record 71 | upernavik
# Processing Record 72 | auki
# Processing Record 73 | shieli
# Processing Record 74 | fairbanks
# Processing Record 75 | bealanana
# Processing Record 76 | luderitz
# Processing Record 77 | vestmanna
# Processing Record 78 | arenys de mar
# Could Not Process Record 79 | City not found
# Processing Record 80 | french harbor
# Processing Record 81 | bethel
# Could Not Process Record 82 | City not found
# Processing Record 83 | lismore
# Processing Record 84 | vardo
# Processing Record 85 | geraldton
# Processing Record 86 | say
# Could Not Process Record 87 | City not found
# Processing Record 88 | solnechnyy
# Processing Record 89 | khatanga
# Processing Record 90 | natal
# Processing Record 91 | dalbandin
# Processing Record 92 | yanji
# Processing Record 93 | hithadhoo
# Processing Record 94 | iqaluit
# Processing Record 95 | east london
# Processing Record 96 | butaritari
# Processing Record 97 | hobart
# Processing Record 98 | santa catalina
# Processing Record 99 | atuona
# Processing Record 100 | norman wells
# Could Not Process Record 101 | City not found
# Processing Record 102 | okato
# Processing Record 103 | mar del plata
# Processing Record 104 | saint george
# Could Not Process Record 105 | City not found
# Processing Record 106 | stromness
# Processing Record 107 | salalah
# Processing Record 108 | georgetown
# Processing Record 109 | erzincan
# Processing Record 110 | itarema
# Processing Record 111 | gat
# Processing Record 112 | dingle
# Processing Record 113 | maceio
# Processing Record 114 | savannah bight
# Could Not Process Record 115 | City not found
# Processing Record 116 | saskylakh
# Processing Record 117 | linhares
# Processing Record 118 | arraial do cabo
# Processing Record 119 | bredasdorp
# Could Not Process Record 120 | City not found
# Processing Record 121 | codrington
# Could Not Process Record 122 | City not found
# Processing Record 123 | vao
# Processing Record 124 | kurchum
# Processing Record 125 | dunedin
# Processing Record 126 | sao filipe
# Could Not Process Record 127 | City not found
# Could Not Process Record 128 | City not found
# Processing Record 129 | bodden town
# Processing Record 130 | mataura
# Processing Record 131 | saint-augustin
# Processing Record 132 | praia da vitoria
# Processing Record 133 | cherskiy
# Processing Record 134 | honningsvag
# Processing Record 135 | bekhteyevka
# Processing Record 136 | aklavik
# Processing Record 137 | iskateley
# Processing Record 138 | genc
# Processing Record 139 | sangar
# Processing Record 140 | aksu
# Processing Record 141 | kehra
# Processing Record 142 | mehamn
# Processing Record 143 | ponta do sol
# Processing Record 144 | thompson
# Processing Record 145 | kidal
# Processing Record 146 | boa vista
# Processing Record 147 | puerto ayora
# Could Not Process Record 148 | City not found
# Processing Record 149 | cidreira
# Processing Record 150 | mvuma
# Processing Record 151 | mount gambier
# Processing Record 152 | les cayes
# Processing Record 153 | shingu
# Processing Record 154 | mayo
# Processing Record 155 | anloga
# Processing Record 156 | boguchany
# Processing Record 157 | ayaviri
# Processing Record 158 | sorong
# Processing Record 159 | lompoc
# Processing Record 160 | hasaki
# Processing Record 161 | college
# Processing Record 162 | vila velha
# Processing Record 163 | leningradskiy
# Processing Record 164 | pevek
# Processing Record 165 | yichang
# Processing Record 166 | torbay
# Processing Record 167 | feijo
# Processing Record 168 | luba
# Processing Record 169 | edd
# Processing Record 170 | altay
# Processing Record 171 | korla
# Processing Record 172 | ancud
# Processing Record 173 | zhifang
# Processing Record 174 | kailua
# Processing Record 175 | chaiyaphum
# Processing Record 176 | cape town
# Processing Record 177 | xining
# Processing Record 178 | chingirlau
# Processing Record 179 | isangel
# Processing Record 180 | kavieng
# Processing Record 181 | rio grande
# Processing Record 182 | tuktoyaktuk
# Processing Record 183 | souillac
# Processing Record 184 | port blair
# Processing Record 185 | bathsheba
# Could Not Process Record 186 | City not found
# Processing Record 187 | bengkulu
# Processing Record 188 | tual
# Processing Record 189 | hurghada
# Could Not Process Record 190 | City not found
# Processing Record 191 | lebu
# Processing Record 192 | baia mare
# Processing Record 193 | nishihara
# Processing Record 194 | union
# Could Not Process Record 195 | City not found
# Processing Record 196 | amahai
# Processing Record 197 | champerico
# Processing Record 198 | pangkalanbuun
# Processing Record 199 | nyimba
# Processing Record 200 | narsaq
# Processing Record 201 | tuatapere
# Processing Record 202 | nantucket
# Processing Record 203 | tasiilaq
# Processing Record 204 | wanaka
# Processing Record 205 | amapa
# Processing Record 206 | sambava
# Processing Record 207 | coahuayana
# Could Not Process Record 208 | City not found
# Processing Record 209 | gazanjyk
# Processing Record 210 | karratha
# Processing Record 211 | hofn
# Processing Record 212 | yarada
# Processing Record 213 | nongstoin
# Processing Record 214 | shache
# Processing Record 215 | mecca
# Processing Record 216 | cravo norte
# Processing Record 217 | lavrentiya
# Processing Record 218 | latur
# Processing Record 219 | komsomolskiy
# Processing Record 220 | pangnirtung
# Processing Record 221 | yumen
# Processing Record 222 | buluang
# Processing Record 223 | goderich
# Processing Record 224 | zhigansk
# Processing Record 225 | morro bay
# Processing Record 226 | havelock
# Could Not Process Record 227 | City not found
# Processing Record 228 | golden
# Processing Record 229 | seoul
# Processing Record 230 | ust-tsilma
# Processing Record 231 | shimoda
# Processing Record 232 | telma
# Processing Record 233 | carnarvon
# Processing Record 234 | promyshlennyy
# Processing Record 235 | kletnya
# Processing Record 236 | bac lieu
# Processing Record 237 | abha
# Processing Record 238 | olmos
# Processing Record 239 | bannu
# Processing Record 240 | kuala terengganu
# Processing Record 241 | falmouth
# Processing Record 242 | denpasar
# Processing Record 243 | brae
# Processing Record 244 | ca mau
# Processing Record 245 | atar
# Processing Record 246 | aksarka
# Processing Record 247 | channel-port aux basques
# Processing Record 248 | tiksi
# Processing Record 249 | togur
# Processing Record 250 | los llanos de aridane
# Could Not Process Record 251 | City not found
# Processing Record 252 | ishigaki
# Processing Record 253 | saldanha
# Processing Record 254 | rio negrinho
# Processing Record 255 | horbranz
# Processing Record 256 | lensk
# Processing Record 257 | sept-iles
# Processing Record 258 | nador
# Could Not Process Record 259 | City not found
# Processing Record 260 | baykit
# Processing Record 261 | kaeo
# Processing Record 262 | ponta delgada
# Processing Record 263 | coquimbo
# Processing Record 264 | batagay-alyta
# Processing Record 265 | san patricio
# Processing Record 266 | bojnurd
# Processing Record 267 | cedar city
# Processing Record 268 | ostrovnoy
# Processing Record 269 | tignere
# Processing Record 270 | santa barbara
# Processing Record 271 | hay river
# Processing Record 272 | ville-marie
# Processing Record 273 | lorengau
# Processing Record 274 | isiro
# Processing Record 275 | vanimo
# Processing Record 276 | conceicao da barra
# Processing Record 277 | san quintin
# Processing Record 278 | verkhoyansk
# Processing Record 279 | palmer
# Processing Record 280 | hirara
# Processing Record 281 | drumheller
# Processing Record 282 | nizwa
# Processing Record 283 | kavaratti
# Processing Record 284 | qaanaaq
# Processing Record 285 | wielsbeke
# Processing Record 286 | gazli
# Processing Record 287 | ahipara
# Processing Record 288 | alofi
# Processing Record 289 | noumea
# Processing Record 290 | bay roberts
# Processing Record 291 | kerrobert
# Processing Record 292 | cayenne
# Processing Record 293 | walvis bay
# Processing Record 294 | jumla
# Processing Record 295 | kambove
# Processing Record 296 | aregua
# Processing Record 297 | agirish
# Processing Record 298 | balkhash
# Processing Record 299 | venado tuerto
# Could Not Process Record 300 | City not found
# Processing Record 301 | nome
# Could Not Process Record 302 | City not found
# Processing Record 303 | oktyabrskoye
# Processing Record 304 | sur
# Processing Record 305 | beloha
# Processing Record 306 | port-gentil
# Processing Record 307 | mareeba
# Processing Record 308 | solana beach
# Processing Record 309 | talnakh
# Processing Record 310 | richards bay
# Could Not Process Record 311 | City not found
# Processing Record 312 | gigmoto
# Could Not Process Record 313 | City not found
# Processing Record 314 | kembe
# Processing Record 315 | mount isa
# Processing Record 316 | sembakung
# Processing Record 317 | poum
# Processing Record 318 | laguna
# Processing Record 319 | ayr
# Processing Record 320 | acapulco
# Processing Record 321 | roebourne
# Processing Record 322 | kimbe
# Processing Record 323 | vallenar
# Processing Record 324 | swan hill
# Processing Record 325 | sehithwa
# Processing Record 326 | te anau
# Processing Record 327 | provideniya
# Processing Record 328 | victoria point
# Processing Record 329 | henties bay
# Processing Record 330 | marawi
# Processing Record 331 | aranos
# Processing Record 332 | colotlan
# Processing Record 333 | surt
# Processing Record 334 | kamenice nad lipou
# Processing Record 335 | sarangani
# Processing Record 336 | mutis
# Processing Record 337 | phultala
# Processing Record 338 | price
# Could Not Process Record 339 | City not found
# Processing Record 340 | torit
# Processing Record 341 | khawhai
# Processing Record 342 | shatrovo
# Processing Record 343 | kholodnyy
# Could Not Process Record 344 | City not found
# Processing Record 345 | sari
# Processing Record 346 | inhambane
# Processing Record 347 | solin
# Processing Record 348 | salinopolis
# Processing Record 349 | saumur
# Processing Record 350 | paita
# Processing Record 351 | boo
# Processing Record 352 | touros
# Processing Record 353 | katobu
# Processing Record 354 | balabac
# Processing Record 355 | northam
# Processing Record 356 | san cristobal
# Could Not Process Record 357 | City not found
# Processing Record 358 | port lincoln
# Processing Record 359 | scarborough
# Processing Record 360 | vestmannaeyjar
# Processing Record 361 | yubari
# Processing Record 362 | nekrasovka
# Processing Record 363 | banjar
# Processing Record 364 | byron bay
# Processing Record 365 | barentu
# Could Not Process Record 366 | City not found
# Could Not Process Record 367 | City not found
# Processing Record 368 | eyl
# Processing Record 369 | katsuura
# Processing Record 370 | alice springs
# Processing Record 371 | shubarshi
# Processing Record 372 | dhidhdhoo
# Processing Record 373 | qovlar
# Processing Record 374 | healdsburg
# Processing Record 375 | alekseyevsk
# Could Not Process Record 376 | City not found
# Processing Record 377 | chuy
# Could Not Process Record 378 | City not found
# Processing Record 379 | evensk
# Processing Record 380 | murdochville
# Processing Record 381 | namatanai
# Processing Record 382 | santiago del estero
# Processing Record 383 | kalmunai
# Could Not Process Record 384 | City not found
# Processing Record 385 | sayyan
# Processing Record 386 | buyo
# Processing Record 387 | campoverde
# Processing Record 388 | beringovskiy
# Processing Record 389 | road town
# Processing Record 390 | tautira
# Processing Record 391 | naze
# Processing Record 392 | ballina
# Processing Record 393 | coaldale
# Processing Record 394 | lancaster
# Processing Record 395 | saint-georges
# Processing Record 396 | daru
# Processing Record 397 | rubiataba
# Could Not Process Record 398 | City not found
# Processing Record 399 | pathein
# Processing Record 400 | pokhara
# Processing Record 401 | mitsamiouli
# Processing Record 402 | bauta
# Processing Record 403 | serov
# Processing Record 404 | adrar
# Processing Record 405 | tecoanapa
# Processing Record 406 | wilmington
# Processing Record 407 | yerbogachen
# Processing Record 408 | borba
# Processing Record 409 | constitucion
# Processing Record 410 | sitka
# Processing Record 411 | mamonovo
# Processing Record 412 | tabas
# Processing Record 413 | sisimiut
# Processing Record 414 | fox lake
# Processing Record 415 | havoysund
# Processing Record 416 | ambon
# Processing Record 417 | zakamensk
# Processing Record 418 | asfi
# Processing Record 419 | lufilufi
# Processing Record 420 | mosetse
# Processing Record 421 | mogadishu
# Processing Record 422 | lagoa
# Processing Record 423 | matara
# Processing Record 424 | bambanglipuro
# Processing Record 425 | sinnamary
# Processing Record 426 | peruibe
# Processing Record 427 | suzhou
# Processing Record 428 | bacolod
# Processing Record 429 | cap malheureux
# Processing Record 430 | manzanillo
# Processing Record 431 | esil
# Could Not Process Record 432 | City not found
# Processing Record 433 | nyurba
# Processing Record 434 | berlevag
# Processing Record 435 | ambilobe
# Processing Record 436 | camargo
# Processing Record 437 | portobelo
# Processing Record 438 | kazanka
# Processing Record 439 | srednekolymsk
# Processing Record 440 | faanui
# Processing Record 441 | hualmay
# Processing Record 442 | chernyshevskiy
# Processing Record 443 | kalmar
# Processing Record 444 | borogontsy
# Processing Record 445 | asuncion
# Processing Record 446 | egvekinot
# Processing Record 447 | tommot
# Processing Record 448 | taguatinga
# Processing Record 449 | boffa
# Processing Record 450 | bubaque
# Processing Record 451 | sao jose da coroa grande
# Processing Record 452 | medicine hat
# Processing Record 453 | severodvinsk
# Processing Record 454 | eureka
# Processing Record 455 | piacabucu
# Processing Record 456 | dickinson
# Could Not Process Record 457 | City not found
# Processing Record 458 | zalegoshch
# Processing Record 459 | auburndale
# Could Not Process Record 460 | City not found
# Processing Record 461 | dubuque
# Processing Record 462 | qaqortoq
# Processing Record 463 | krasnoselkup
# Processing Record 464 | ilulissat
# Processing Record 465 | eldoret
# Processing Record 466 | isla vista
# Processing Record 467 | marienburg
# Processing Record 468 | severo-kurilsk
# Could Not Process Record 469 | City not found
# Processing Record 470 | longido
# Processing Record 471 | awjilah
# Processing Record 472 | parabel
# Processing Record 473 | petropavlovsk-kamchatskiy
# Processing Record 474 | bonavista
# Processing Record 475 | baruun-urt
# Processing Record 476 | dezful
# Processing Record 477 | caravelas
# Processing Record 478 | bondo
# Processing Record 479 | marquette
# Processing Record 480 | eenhana
# Processing Record 481 | tel aviv-yafo
# Processing Record 482 | asau
# Processing Record 483 | lingao
# Processing Record 484 | aleksandrov gay
# Processing Record 485 | vostok
# Processing Record 486 | dumingag
# Processing Record 487 | tambovka
# Processing Record 488 | nyaunglebin
# Processing Record 489 | abatskoye
# Processing Record 490 | sechura
# Processing Record 491 | axim
# Processing Record 492 | lipari
# Processing Record 493 | homer
# Processing Record 494 | saint-joseph
# Processing Record 495 | quepos
# Could Not Process Record 496 | City not found
# Processing Record 497 | kenai
# Processing Record 498 | balkanabat
# Processing Record 499 | klaksvik
# Processing Record 500 | portland
# Processing Record 501 | misratah
# Processing Record 502 | novikovo
# Processing Record 503 | srikakulam
# Processing Record 504 | gisborne
# Processing Record 505 | broken hill
# Could Not Process Record 506 | City not found
# Processing Record 507 | moree
# Processing Record 508 | olafsvik
# Processing Record 509 | wagar
# Processing Record 510 | nabire
# Processing Record 511 | morondava
# Processing Record 512 | erdenet
# Processing Record 513 | olga
# Processing Record 514 | trincomalee
# Processing Record 515 | tezu
# Processing Record 516 | atherton
# Processing Record 517 | semirom
# Processing Record 518 | verkhnetulomskiy
# Processing Record 519 | hauknes
# Processing Record 520 | faya
# Processing Record 521 | ransang
# Processing Record 522 | arteaga
# Processing Record 523 | lotofaga
# Processing Record 524 | hambantota
# Processing Record 525 | okha
# Processing Record 526 | karacakoy
# Processing Record 527 | san matias
# Processing Record 528 | kon tum
# Processing Record 529 | svetlogorsk
# Processing Record 530 | lawrence
# Processing Record 531 | beira
# Processing Record 532 | nouakchott
# Could Not Process Record 533 | City not found
# Processing Record 534 | mitu
# Processing Record 535 | tando muhammad khan
# Processing Record 536 | arona
# Processing Record 537 | sakhnovshchyna
# Processing Record 538 | la ronge
# Processing Record 539 | karaton
# Could Not Process Record 540 | City not found
# Processing Record 541 | shalinskoye
# Could Not Process Record 542 | City not found
# Processing Record 543 | muravlenko
# Processing Record 544 | tukrah
# Processing Record 545 | mersing
# Processing Record 546 | mercedes
# Processing Record 547 | santa isabel do rio negro
# Processing Record 548 | fortuna
# Could Not Process Record 549 | City not found
# Processing Record 550 | guerrero negro
# Processing Record 551 | garowe
# Processing Record 552 | caconda
# Processing Record 553 | paignton
# Processing Record 554 | awbari
# Processing Record 555 | necochea
# Processing Record 556 | conakry
# Processing Record 557 | hami
# Processing Record 558 | keetmanshoop
# Processing Record 559 | ylivieska
# Processing Record 560 | paamiut
# Processing Record 561 | waipawa
# Processing Record 562 | westport
# Processing Record 563 | prieska
# Processing Record 564 | bilibino
# Processing Record 565 | vila franca do campo
# Processing Record 566 | cubuk
# Processing Record 567 | black river
# Processing Record 568 | avera
# Processing Record 569 | raudeberg
# Processing Record 570 | manta
# Could Not Process Record 571 | City not found
# Processing Record 572 | tingi
# Processing Record 573 | dinan
# Processing Record 574 | tutoia
# Processing Record 575 | kitaibaraki
# Processing Record 576 | christchurch
# Could Not Process Record 577 | City not found
# Processing Record 578 | stepantsevo
# Processing Record 579 | mwene-ditu
# Processing Record 580 | antofagasta
# Processing Record 581 | gaoua
# Processing Record 582 | jerome
# Processing Record 583 | sungairaya
# Processing Record 584 | hanzhong
# Processing Record 585 | deputatskiy
# Processing Record 586 | reinosa
# Processing Record 587 | losheim
# Could Not Process Record 588 | City not found
# Processing Record 589 | charters towers
# Processing Record 590 | cabedelo
# Processing Record 591 | palu
# Processing Record 592 | puerto escondido
# Processing Record 593 | pisco
# Processing Record 594 | songadh
# Processing Record 595 | dera bugti
# Processing Record 596 | imbituba
# Processing Record 597 | saint-doulchard
# Processing Record 598 | kandalaksha
# Processing Record 599 | huambo
# Processing Record 600 | urumqi
# Processing Record 601 | xingyi
# Could Not Process Record 602 | City not found
# Processing Record 603 | orbottyan
# Processing Record 604 | lakes entrance
# Processing Record 605 | borovsk
# Processing Record 606 | tabou
# Processing Record 607 | bay city
# Could Not Process Record 608 | City not found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Store city weather data in a dataframe:

city_weather_df = pd.DataFrame({
    "City": City,
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max_temp": Max_temp,
    "Wind_speed": Wind_speed
})

city_weather_df
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    port elizabeth          92      ZA  1586650267        63 -33.92   25.57
# 1          sandwick         100      GB  1586650185        81  60.00   -1.25
# 2       new norfolk          40      AU  1586650004        58 -42.78  147.06
# 3            chokwe           0      MZ  1586650267        83 -24.53   32.98
# 4             muros          90      ES  1586650267        93  42.78   -9.06
# ..              ...         ...     ...         ...       ...    ...     ...
# 554       orbottyan           8      HU  1586650313        52  47.69   19.28
# 555  lakes entrance          86      AU  1586650313        73 -37.88  147.98
# 556         borovsk          11      RU  1586650313        79  55.21   36.49
# 557           tabou          99      CI  1586650313        82   4.42   -7.35
# 558        bay city           1      US  1586650313        40  43.59  -83.89
#
#      Max_temp  Wind_speed
# 0       62.60        5.82
# 1       46.40       27.51
# 2       55.99       19.46
# 3       67.57        4.47
# 4       55.00        4.70
# ..        ...         ...
# 554     50.00        2.24
# 555     55.99        1.01
# 556     28.40        6.71
# 557     80.04        3.40
# 558     54.00        6.93
#
# [559 rows x 9 columns]

# %%
# Export city weather data to a .csv file:

city_weather_df.to_csv(output_data_file, index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Max_temp"])

today = date.today()
plt.xlabel("Latitude")
plt.ylabel("Maximum temperature in Degrees Celsius")
plt.title(f"City Latitude vs. Temperature - {today}")
plt.grid(alpha=0.4)

plt.savefig("data_output/Images/Lat_vs_Temp.png")
plt.show()

# Based on the plot below, temperature is higher in cities near the equator. The further a city is from the equator, the colder the temperature.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"])

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity - {today}")
plt.grid(alpha=0.4)

plt.savefig("data_output/Images/Lat_vs_Humidity.png")
plt.show()

# Based on the plot below, cities with latitudes between -20 degrees and 0 degree all have relatively high humidity levels. 
# The same can be said of cities with latitudes between 60 degrees and 80 degrees. Other cities have high levels of variation in humidity levels.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"])

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness - {today}")
plt.grid(alpha=0.4)

plt.savefig("data_output/Images/Lat_vs_Cloudiness.png")
plt.show()

# According to the plot below, there are high levels of variation in cloudiness among all cities in the sample.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Wind_speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed - {today}")
plt.grid(alpha=0.4)

plt.savefig("data_output/Images/Lat_vs_WindSpeed.png")
plt.show()

# According to the plot below, wind speed tends to vary greatly among all cities in the sample.

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots:

def lin_regress(x_values, y_values, y_axis_label, hemisphere):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    
    plt.xlabel("City Latitude")
    plt.ylabel(y_axis_label)
    plt.grid(alpha=0.4)
    plt.title(f"{hemisphere} Hemisphere: City Latitude vs. {y_axis_label} - {today}")
    
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_df = city_weather_df.loc[city_weather_df["Lat"] >= 0]
southern_df = city_weather_df.loc[city_weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Max_temp"]
y_axis_label = "Max Temperature"
hemisphere = "Northern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/North_Lat_vs_Temp_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is a strong inverse correlation between city latitude and temperature in the northern hemisphere.
# Out:
# The r-squared is: 0.8242380845167979

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Max_temp"]
y_axis_label = "Max Temperature"
hemisphere = "Southern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/South_Lat_vs_Temp_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is a direct correlation between city latitude and temperature in the southern hemisphere.
# Out:
# The r-squared is: 0.48246437200188774

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]
y_axis_label = "Humidity (%)"
hemisphere = "Northern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/North_Lat_vs_Humidity_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is no correlation between city latitude and humidity in the northern hemisphere.
# Out:
# The r-squared is: 0.03801812615012337

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]
y_axis_label = "Humidity (%)"
hemisphere = "Southern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/South_Lat_vs_Humidity_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is no correlation between city latitude and humidity in the southern hemisphere
# Out:
# The r-squared is: 0.049986712659501054

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]
y_axis_label = "Cloudiness (%)"
hemisphere = "Northern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/North_Lat_vs_Cloudiness_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is no correlation between city latitude and cloudiness in the northern hemisphere
# Out:
# The r-squared is: 0.05266785155491008

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]
y_axis_label = "Cloudiness (%)"
hemisphere = "Southern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/South_Lat_vs_Cloudiness_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is no correlation between city latitude and cloudiness in the southern hemisphere
# Out:
# The r-squared is: 0.002273318986115207

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Wind_speed"]
y_axis_label = "Wind Speed (mph)"
hemisphere = "Northern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/North_Lat_vs_WindSpeed_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is no correlation between city latitude and wind speed in the northern hemisphere
# Out:
# The r-squared is: 0.03474515712088459

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Wind_speed"]
y_axis_label = "Wind Speed (mph)"
hemisphere = "Southern"

lin_regress(x_values, y_values, y_axis_label, hemisphere)

plt.savefig("data_output/Images/North_Lat_vs_WindSpeed_LinRegress.png")
plt.show()

# Based on the linear regression plot below, there is a weak inverse correlation between city latitude and wind speed in the southern hemisphere
# Out:
# The r-squared is: 0.15176226998184034
